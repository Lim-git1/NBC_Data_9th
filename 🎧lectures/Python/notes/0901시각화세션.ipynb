# %% [markdown]
# #### **Matplotlib**
#
# 파이썬에서 가장 기본이 되는 그래프 라이브러리입니다. 여러 종류의 차트(선형 차트, 막대 차트, 산점도 등)를 직접 그릴 수 있고, 많은 커스터마이징이 가능합니다.
#
#
# #### **Seaborn**
#
# Matplotlib 기반으로 만들어진 좀 더 쉬운 시각화 라이브러리입니다. 데이터프레임(Pandas)과 잘 연결되고, 기본 디자인도 깔끔하게 설정되어 있어서 적은 코드로 멋진 그래프를 만들 수 있습니다.

# %%
# matplotlib seaborn pandas 라이브러리 설치
# pip install matplotlib seaborn pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 9.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 8.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.4/253.4 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 6.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'AppleGothic'

# %%
# 예시 데이터
x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

plt.plot(x, y, marker='o')  # 기본 선형 그래프, 각 점에 동그라미 표시 추가
plt.title("기본 라인 그래프")   
plt.xlabel("X축")
plt.ylabel("Y축")
plt.show()

# %%
import seaborn as sns
import pandas as pd

# 샘플 데이터프레임
df = pd.DataFrame({
    'month': ['Jan','Feb','Mar','Apr'],
    'sales': [10, 20, 15, 25]
})

sns.lineplot(x='month', y='sales', data=df)
plt.title("Seaborn 라인 그래프")
plt.show()

# %% [markdown]
# ### **선형 그래프**
#
# **언제 사용하지?**  :   시계열 자료, 순서가 있는 데이터 추이
#
# - Matplotlib: `plt.plot(x, y)`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

days = ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
sales = [10, 12, 9, 13, 15, 14, 11]

plt.plot(days, sales, marker="o")
plt.title("Daily Sales")
plt.xlabel("Day")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# - Seaborn: `sns.lineplot(x=..., y=..., data=...)`

# %%
df = pd.DataFrame({"day": days, "sales": sales})
sns.lineplot(x="day", y="sales", data=df, marker="o")
plt.title("Daily Sales (Seaborn)")
plt.show()

# %% [markdown]
# ### **막대 그래프**
#
# **언제 사용하지?** : 범주/분류에 따라 값을 비교
#
# - Matplotlib :
#
#   - `plt.barh(fruits, stocks)` -> 수평
#
#   - `plt.bar(fruits, stocks)` -> 수직

# %%
fruits = ["Apple","Banana","Cherry"]
stocks = [30, 18, 25]

# 수평
plt.barh(fruits, stocks) 
# plt.bar(fruits, stocks) -> 수직
plt.title("Fruit Stocks")
plt.xlabel("Count")
plt.show()

# %% [markdown]
# - Seaborn : `sns.barplot(x=..., y=..., data=...)`

# %%
basket = pd.DataFrame({"fruit": ["Apple","Banana","Apple","Cherry","Apple"], "stocks":[30,18,25,27,55]})
sns.barplot(x='fruit', y='stocks', data=basket)
plt.title("Fruit Count (Auto)")
plt.show()

# %% [markdown]
# ### **산점도(Scatter Plot)**
#
# **언제 사용하지?** : 두 변수 사이의 상관관계
#
# - Matplotlib : `plt.scatter(x, y)`

# %%
height = [160, 165, 170, 175, 180]
weight = [55, 60, 65, 72, 80]

plt.scatter(height, weight)
plt.title("Height vs Weight")
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.show()

# %% [markdown]
# - Seaborn : `sns.scatterplot(x='col1', y='col2', data=df)`

# %%
df = pd.DataFrame({
    "height": [160,165,170,175,180,168,172],
    "weight": [55,60,65,72,80,58,67],
    "sex":    ["F","M","M","M","M","F","F"]
})
sns.scatterplot(x="height", y="weight", hue="sex", data=df)
plt.title("Height vs Weight by Sex")
plt.show()

# %% [markdown]
# ### **히스토그램**
#
# **언제 사용할까?** : 연속형데이터 분포 (어디에 몰려있지? 어떤 구간이 많지?)
#
# Matplotlib: `plt.hist(data, bins=10)`

# %%
scores = [55, 60, 62, 65, 70, 72, 75, 78, 80, 82, 85, 88]
plt.hist(scores, bins=5)  # 구간 5개로 쪼개기
plt.title("Score Distribution")
plt.xlabel("Score"); plt.ylabel("Count")
plt.show()

# %% [markdown]
# Seaborn: `sns.histplot(data=df['some_column'])`

# %%
df = pd.DataFrame({"score": scores})
sns.histplot(data=df, x="score", bins=5)  # kde=True(부드러운 곡선) 옵션 가능
plt.title("Score Distribution (Seaborn)")
plt.show()

# %% [markdown]
# ### **박스플롯(Box Plot) & 바이올린 플롯(Violin Plot)**
#
# **언제 사용하지?** : 범주별 데이터의 중앙값, 사분위수, 이상치
#
# * Seaborn 구현이 더 간단하다.

# %%
df = pd.DataFrame({
    "class": ["A","A","A","B","B","B"],
    "score": [70, 75, 80, 65, 68, 78]
})
sns.boxplot(x="class", y="score", data=df)
plt.title("Scores by Class (Boxplot)")
plt.show()

# %%
# order : 순서, inner : 중앙값/사분위선 표시
sns.violinplot(x="class", y="score", data=df, inner="quartile")
plt.title("Scores by Class (Violin)")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 그래프 꾸미기

# %%
# 제목, 축 레이블
plt.title("그래프 제목")
plt.xlabel("X축 이름")
plt.ylabel("Y축 이름")

# 사이즈
plt.figure(figsize=(6,8))

# 간격
plt.axis([x시작,x끝,y시작,y끝])
# Out:
# Text(0, 0.5, 'Y축 이름')

# %%
# 범례(legend) 달기

# matplotlib
import matplotlib.pyplot as plt

x = [1,2,3,4]
plt.plot(x, [1,3,2,4], label="A선")
plt.plot(x, [2,2,3,3], label="B선")
plt.legend()  # label 달아둔 아티스트를 자동 수집
plt.show()

# seaborn
# hue=, style=, size=를 쓰면 자동으로 범례가 생깁니다.
import seaborn as sns
tips = sns.load_dataset("tips")

ax = sns.scatterplot(data=tips, x="total_bill", y="tip")  # 자동 범례
ax.legend(title="요일")  # 제목만 살짝 바꾸기
plt.show()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # IMDB 5000 Movie Dataset 시각화 실습

# %%
# plotly 라이브러리 설치
# pip install plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 9.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.0/401.0 kB 8.5 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('../data/movie_metadata.csv')

# %% [markdown]
# ## 막대그래프: 연도별 영화 개수

# %% [markdown]
# ### Matplotlib을 사용한 막대그래프

# %%
import matplotlib.pyplot as plt

# 연도별 영화 개수 계산
movies_per_year = df['title_year'].value_counts().sort_index()  # 연도별 count (연도 정렬)
years = movies_per_year.index.astype(int)
counts = movies_per_year.values

# 막대그래프 그리기
plt.figure(figsize=(6,4))
plt.bar(years, counts, color='skyblue', width=0.6)
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Number of Movies Released Each Year')
plt.xticks(years, rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Seaborn을 사용한 막대그래프

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
sns.barplot(x=movies_per_year.index, y=movies_per_year.values, palette='pastel')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.title('Number of Movies Released Each Year (Seaborn)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mt/b5bzczgn14s85rhfsvnlr33h0000gn/T/ipykernel_72888/349662737.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=movies_per_year.index, y=movies_per_year.values, palette='pastel')

# %% [markdown]
# ### Plotly를 사용한 막대그래프

# %%
import plotly.express as px

fig = px.bar(
    x=movies_per_year.index,
    y=movies_per_year.values,
    labels={'x':'Year', 'y':'Number of Movies'},
    title='Number of Movies Released Each Year'
)
fig.show()

# %% [markdown]
# ## 산점도: 예산 vs 수익

# %% [markdown]
# ### Matplotlib을 사용한 산점도

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['budget'], df['gross'], color='teal', alpha=0.7) #alpha는 투명도
plt.xlabel('Budget (USD)')
plt.ylabel('Gross Revenue (USD)')
plt.title('Budget vs Gross Revenue')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Seaborn을 사용한 산점도

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x='budget', y='gross', color='purple')
plt.xlabel('Budget (USD)')
plt.ylabel('Gross Revenue (USD)')
plt.title('Budget vs Gross Revenue (Seaborn)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 히트맵: 상관관계 행렬
#
# **상관계수(correlation coefficient)란?**
#
# : 두 변수(예: height, weight)가 얼마나 선형적으로 관련이 있는지를 -1 ~ 1 사이의 값으로 표현한 것.
#
# - +1 → 완벽한 양의 상관관계 (한 변수가 커지면 다른 변수도 커짐)
#
# - -1 → 완벽한 음의 상관관계 (한 변수가 커지면 다른 변수는 작아짐)
#
# - 0 → 선형적 관계 없음

# %% [markdown]
# ### Matplotlib을 사용한 히트맵

# %%
# 선택한 수치형 변수들의 상관계수 행렬 계산
cols = ['duration', 'num_voted_users', 'budget', 'gross', 'imdb_score']
corr_matrix = df[cols].corr().values  # 또는 df[cols].corr().values

plt.figure(figsize=(5,4))
im = plt.imshow(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Movie Attributes')
# 축 눈금 및 라벨 설정
plt.xticks(range(len(cols)), cols, rotation=45, ha='right')
plt.yticks(range(len(cols)), cols)
# 컬러바 추가
plt.colorbar(im)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Seaborn을 사용한 히트맵

# %%
corr_df = df[cols].corr()  # 상관계수를 DataFrame으로 얻기
plt.figure(figsize=(5,4))
sns.heatmap(corr_df, annot=True, cmap='coolwarm', center=0) # annot : 상관계수표시
plt.title('Correlation Heatmap of Movie Attributes (Seaborn)')
plt.tight_layout()
plt.show()

# %%
pip install nbformat
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.5/353.5 kB 8.1 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
