# %% [markdown]
# # 네이버 연관검색어 수집하기
#
# ### 개요
#
# 이 실습에서는 네이버 자동완성 API를 활용하여 특정 검색어에 대한 연관검색어를 수집하는 방법을 학습합니다.
# 크롬 개발자 도구를 활용해 공식 API가 아닌 네이버 자동완성 서비스의 요청 구조를 분석하여 데이터를 수집하는 방법을 배웁니다

# %% [markdown]
# ## 1. 필요한 라이브러리 설치

# %%
# !pip install requests

# %% [markdown]
# ## 2. API 요청에 필요한 기본 정보 설정
# - 네이버 API에 요청을 보내기 위한 기본 정보를 설정

# %% [markdown]
# [네이버 검색창 '파이썬' 자동완성 리스트](https://ac.search.naver.com/nx/ac?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC&con=1&frm=nv&ans=2&r_format=json&r_enc=UTF-8&r_unicode=0&t_koreng=1&run=2&rev=4&q_enc=UTF-8&st=100&ackey=5s04eqgu&_callback=_jsonp_5)
#
# [네이버 검색창 '데이터' 자동완성 리스트](https://ac.search.naver.com/nx/ac?q=%EB%8D%B0%EC%9D%B4%ED%84%B0&st=100)

# %%
import requests

# 네이버 연관검색어 자동 완성 API URL
base_url = "https://ac.search.naver.com/nx/ac"

# 브라우저 정보 설정 (User-Agent)
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
headers = {
    'User-Agent': user_agent
}

# 검색어 설정
search_term = "태블로"

# API 요청 파라미터 설정
params = {
    'q': search_term,  # 검색어
    'st': 100 
}

# %% [markdown]
# ## 3. API 요청 보내기
# - 설정한 정보를 바탕으로 API에 요청

# %%
try:
    # API 요청 보내기
    response = requests.get(base_url, params=params, headers=headers)
    
    # 응답 상태 코드 확인
    print(f"응답 상태 코드: {response.status_code}")
    
    # JSON 형식의 응답 데이터 확인
    data = response.json()
    print("\n응답 데이터:")
    print(data)
    
except requests.exceptions.RequestException as e:
    print(f"에러 발생: {e}")
# Out:
# 응답 상태 코드: 200
#
# 응답 데이터:
# {'query': ['태블로'], 'items': [[['태블로'], ['태블로 자격증'], ['태블로 퍼블릭'], ['태블로 교육'], ['태블로 가격'], ['태블로 대시보드'], ['태블로 무료'], ['태블로 시각화'], ['태블로 자격증 후기'], ['태블로 사용법']]]}

# %% [markdown]
# ## 4. 연관검색어 추출하기
# - 응답 데이터에서 연관검색어만 추출

# %%
# 연관검색어 리스트 추출
related_searches = [item[0] for item in data['items'][0]]

# 결과 출력
print(f"\n'{search_term}'의 연관검색어:")
for i, term in enumerate(related_searches, 1):
    print(f"{i}. {term}")

# %% [markdown]
# ## 5. 재사용성을 위한 함수화

# %%
import requests

def get_related_searches(search_term):
    """
    네이버 연관검색어를 가져오는 함수
    Args:
        search_term (str): 검색하고자 하는 단어
    Returns:
        list: 연관검색어 리스트
    """

    #사용자 User-Agent 
    user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
    headers =  {
        'User-Agent': user_agent
    }

    # 네이버 자동완성 API URL
    base_url = "https://ac.search.naver.com/nx/ac"
    
    # 검색어를 URL 인코딩하여 파라미터 구성
    params = {
        'q': search_term,
        'st': 100
    }
    
    try:
        # API 요청
        response = requests.get(base_url, params=params, headers=headers)

        # JSON 응답 파싱
        data = response.json()
        print(data)
        # 연관검색어 추출 (items[0]의 각 항목의 첫번째 요소)
        related_searches = [item[0] for item in data['items'][0]]
        return related_searches
        
    except requests.exceptions.RequestException as e:
        print(f"에러 발생: {e}")
        return []

# %%
print("<< 네이버 연관 검색어 가져오기 >>")
search_term = "삼성전자"

# 연관검색어 가져오기
related_terms = get_related_searches(search_term)

# 결과 출력
if related_terms:
    print("\n연관검색어:")
    for i, term in enumerate(related_terms, 1):
        print(f"{i}. {term}")
else:
    print("연관검색어를 가져오는데 실패했습니다.")
